# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import SessionNotCreatedException
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
import openpyxl
import datetime
import time
import pandas as pd

# %% [markdown]
# ### 동적 웹 크롤링

# %% [markdown]
# #### 맛집 블로그 포스트 100개 크롤링 - 제목, url, 장소명

# %%
url = "https://section.blog.naver.com/ThemePost.naver?directoryNo=29&activeDirectorySeq=3&currentPage=1"

try:
    driver = webdriver.Chrome()
    #크롬 드라이버 설치 링크 : https:storage.googleapis.com/chrome-for-testing-public/127.0.6533.72/win64/chromedriver-win64.zip
    #압축 해제 후, driver.exe는 실행파일과 같은 위치 혹은 하위에 존재해야 함
    #사내망에선 드라이버의 물리적 위치 괄호 안에 지정해줘야 함
except SessionNotCreatedException as e:
    print("SessionNotCreatedExceptions이 발생했습니다:", str(e))
driver.get(url)
time.sleep(3)

# %%
post_titles = driver.find_elements(By.CLASS_NAME,'title_post')

crawler_time = datetime.datetime.now().strftime('%Y-%m-%d %H:%M')
crawler_date = datetime.datetime.now().strftime('%Y%m%d')
print(crawler_time)
App = "Naver Blog"
data = []

print("-----네이버 블로그 - 맛집 포스트-----")
for page in range(1,3): ##1~2페이지까지
    driver.find_element(By.XPATH, '/html/body/ui-view/div/main/div[1]/div/section/div[2]/div[11]/span[{}]/a'.format(page)).click()
    time.sleep(2)

    #포스트 제목
    post_titles = driver.find_elements(By.CLASS_NAME,'title_post')

    #포스트 url
    post_urls = driver.find_elements(By.CLASS_NAME,'desc_inner')
    urls = []
    for i in post_urls :
        href = i.get_attribute('href')
        print(href)
        urls.append(href)

    for idx, post_title in enumerate(post_titles[9:]): ## Top 3 제거(제목너무 짧음), 공백 행 제거
        title = post_title.text
        line_data = []
        line_data.append(App)
        line_data.append(title)
        line_data.append(urls[idx])
        line_data.append(crawler_time)
        data.append(line_data)

df = pd.DataFrame(data, columns= ['App', 'Post Title', 'URL', 'Crawler Time'])
df.index = df.index+1
df
# Out:
# 2024-07-30 22:26
# -----네이버 블로그 - 맛집 포스트-----
# https://blog.naver.com/ganzzajang/223529613762
# https://blog.naver.com/stiearth/223530597179
# https://blog.naver.com/yen_tudio/223530771129
# https://blog.naver.com/lucefw/223530507254
# https://blog.naver.com/thx_ummd/223530558030
# https://blog.naver.com/hungry_hing/223530949319
# https://blog.naver.com/donggue918/223530353174
# https://blog.naver.com/1115hq/223530250764
# https://blog.naver.com/gim_melting/223530984994
# https://blog.naver.com/matcumentary/223530660211
# https://blog.naver.com/juuu-s/223530636934
# https://blog.naver.com/lovelypoky/223530552568
# https://blog.naver.com/ms5306/223530363397
# https://blog.naver.com/matcumentary/223530332726
# https://blog.naver.com/honey126/223530301035
# https://blog.naver.com/hahehe-/223530260685
# https://blog.naver.com/h_ingdi/223530813918
# https://blog.naver.com/alpano/223530560147
# https://blog.naver.com/eunizzang73/223530553813
# https://blog.naver.com/ostar0319/223530401408
#            App                                         Post Title  \
# 1   Naver Blog  부산 송정 맛집 민물장어덮밥이 기가 막힌 흑송 송정 본점 공격 후기 (부산 송정해수...
# 2   Naver Blog                                역삼동 소고기 역시 호박식당이였어요
# 3   Naver Blog     서초역 점심 맛집 교대역 맛집 룸식당 일식 대서양 모듬회 정식 서초역 회식 모임장소
# 4   Naver Blog                         구제주 가성비 맛집 부명 주마한우 22,500원
# 5   Naver Blog                   미아사거리맛집 명륜진사갈비에서 후려페퍼스테이크 먹고 왔어요
# 6   Naver Blog                        신사역 근처 맛집 가로수길 스키야키 hon스키야키
# 7   Naver Blog                          대구 동인동 신상 카페 푸딩 맛집 키츠네 후기
# 8   Naver Blog                  만족했던 목포 근대역사관 맛집 목포 개골박 통낙지육개장 후기
# 9   Naver Blog                       속초 해수욕장 오션뷰 카페 셜터 독특한 디저트 맛집
# 10  Naver Blog          경기광주 중국집 짜장면 짬뽕 탕수육이 맛있는 장지동 맛집 신의한수 보양짬뽕
# 11  Naver Blog                 합정역 맛집 홍대밥집 라오 아시안 비스트로 새우팟타이 쏨땀치킨
# 12  Naver Blog                             서래마을 파스타 맛집 비스트로누 디너코스
# 13  Naver Blog                     여수 오동도 맛집 엑스포역 근처 횟집 추천 엑스포삼포차
# 14  Naver Blog                   강남 족발 맛집 구성 좋고 맛도 일품인 강남구청역 팔당족발
# 15  Naver Blog                        평택 시모네 카페, 두바이 초콜릿 타르트 먹었어요
# 16  Naver Blog                             철산 점심 생각보다 맛있었던 의외의 장소
# 17  Naver Blog                    파주 떡케이크 니모네케이크 시어머니 환갑 숫자케이크 만족
# 18  Naver Blog                 신도림 고기집 월화갈비, 회식하기 좋은 신도림동 돼지갈비 맛집
# 19  Naver Blog                       부산 해운대 카페 딸기케이크 맛집 포시즌베리베이커리
# 20  Naver Blog                     군포 트레이더스 근처 맛집 제주곤이칼국수 군포삼성마을점
#
#                                                  URL      Crawler Time
# 1     https://blog.naver.com/ganzzajang/223529613762  2024-07-30 22:26
# 2       https://blog.naver.com/stiearth/223530597179  2024-07-30 22:26
# 3      https://blog.naver.com/yen_tudio/223530771129  2024-07-30 22:26
# 4         https://blog.naver.com/lucefw/223530507254  2024-07-30 22:26
# 5       https://blog.naver.com/thx_ummd/223530558030  2024-07-30 22:26
# 6    https://blog.naver.com/hungry_hing/223530949319  2024-07-30 22:26
# 7     https://blog.naver.com/donggue918/223530353174  2024-07-30 22:26
# 8         https://blog.naver.com/1115hq/223530250764  2024-07-30 22:26
# 9    https://blog.naver.com/gim_melting/223530984994  2024-07-30 22:26
# 10  https://blog.naver.com/matcumentary/223530660211  2024-07-30 22:26
# 11        https://blog.naver.com/juuu-s/223530636934  2024-07-30 22:26
# 12    https://blog.naver.com/lovelypoky/223530552568  2024-07-30 22:26
# 13        https://blog.naver.com/ms5306/223530363397  2024-07-30 22:26
# 14  https://blog.naver.com/matcumentary/223530332726  2024-07-30 22:26
# 15      https://blog.naver.com/honey126/223530301035  2024-07-30 22:26
# 16       https://blog.naver.com/hahehe-/223530260685  2024-07-30 22:26
# 17       https://blog.naver.com/h_ingdi/223530813918  2024-07-30 22:26
# 18        https://blog.naver.com/alpano/223530560147  2024-07-30 22:26
# 19   https://blog.naver.com/eunizzang73/223530553813  2024-07-30 22:26
# 20     https://blog.naver.com/ostar0319/223530401408  2024-07-30 22:26

# %%
#본문 내 태그

# driver.close()
# post_tags = []
# url = urls[0]
# print(url)

# post_num = url.split("/")[-1]
# print(post_num)
# url = "https://blog.naver.com/juuu-s/223530636934"
# try:
#     driver = webdriver.Chrome()
#     #크롬 드라이버 설치 링크 : https:storage.googleapis.com/chrome-for-testing-public/127.0.6533.72/win64/chromedriver-win64.zip
#     #압축 해제 후, driver.exe는 실행파일과 같은 위치 혹은 하위에 존재해야 함
#     #사내망에선 드라이버의 물리적 위치 괄호 안에 지정해줘야 함
# except SessionNotCreatedException as e:
#     print("SessionNotCreatedExceptions이 발생했습니다:", str(e))
# driver.get(url)
# time.sleep(3)

# contents1 = driver.find_elements(By.CSS_SELECTOR, '#tagList_223530636934')
# contents2 = driver.find_elements(By.CLASS_NAME, 'item pcol2 itemTagront _setTop') #유력
# contents3 = driver.find_elements(By.XPATH, "//span[@class='ell']")

#본문 파싱, 장소명 가장 유력함
import requests
# page = driver.page_source
url = "https://blog.naver.com/juuu-s/223530636934"
html = requests.get(url)
bs_obj = BeautifulSoup(html.text,"html5lib") #몇천 줄 전체 파싱해야 함
restaurant = bs_obj.select_one('#SE-7f43cbda-f36f-4180-a3e6-f8ab1b1b52d8 > div > div > div.se-module.se-module-map-text > a > strong')
print(restaurant)
print(bs_obj)
print(bs_obj.find("div"))
tags = bs_obj.find_all("strong", {"class":"se-map-title"})
print(tags)

# page_url_base = "https://blog.naver.com/ganzzajang/223529613762"
# req = requests.get(page_url_base)
# html = req.content
# soup = BeautifulSoup(html, 'parser')
# print(soup)

# driver.close()

# import requests
# from bs4 impo
# rt BeautifulSoup

# url = 'https://blog.naver.com/ganzzajang/223529613762'

# response = requests.get(url)

# if response.status_code == 200: # 정상 연결시
#     soup = BeautifulSoup(response.text, 'html.parser') # 수프 text 형태로 만들기
#     text = str(soup.find(id='postViewArea')) # 본문 내용만 담긴 css 코드 뽑아내기
#     menu = text.split('점심</span>')[1].split('F3')[0] # 메뉴 나온 내용만 자르기
#     print(menu)

# #div 태그의 특정 클래스를 가져오는 경우
# text = soup.find("div", {"class":'se-module se-module-text'}).find_all('span') # 특정 클래스내에서 span부분 전부 정리
# Out:
# ---------------------------------------------------------------------------
# FeatureNotFound                           Traceback (most recent call last)
# Cell In[90], line 30
#      28 url = "https://blog.naver.com/juuu-s/223530636934"
#      29 html = requests.get(url)
# ---> 30 bs_obj = BeautifulSoup(html.text,"html5lib")
#      31 restaurant = bs_obj.select_one('#SE-7f43cbda-f36f-4180-a3e6-f8ab1b1b52d8 > div > div > div.se-module.se-module-map-text > a > strong')
#      32 print(restaurant)
#
# File c:\Users\Administrator\Desktop\Samsung Welstory\DE\FD_CRAWLING\.venv\lib\site-packages\bs4\__init__.py:250, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     248     builder_class = builder_registry.lookup(*features)
#     249     if builder_class is None:
# --> 250         raise FeatureNotFound(
#     251             "Couldn't find a tree builder with the features you "
#     252             "requested: %s. Do you need to install a parser library?"
#     253             % ",".join(features))
#     255 # At this point either we have a TreeBuilder instance in
#     256 # builder, or we have a builder_class that we can instantiate
#     257 # with the remaining **kwargs.
#     258 if builder is None:
#
# FeatureNotFound: Couldn't find a tree builder with the features you requested: html5lib. Do you need to install a parser library?

# %%
df.to_excel('FD_Crawling_Naver_Blog_{}.xlsx'.format(crawler_date))
driver.close()

# %% [markdown]
# #### 공정위 가맹사업정보제공시스템 정보공개서 크롤링 - 100개

# %%
#빈 sheet 생성
wb = openpyxl.Workbook()
sheet = wb.active
sheet.append(["No.", "Name", "Business", "Representative","Registration_Number", "Init_Date","Type"])
# 번호, 상호, 영업표지, 대표자, 등록번호, 최초등록일, 업종

# %%
url = "https://franchise.ftc.go.kr/mnu/00013/program/userRqst/list.do"
try:
    driver = webdriver.Chrome()
    #크롬 드라이버 설치 링크 : https:storage.googleapis.com/chrome-for-testing-public/127.0.6533.72/win64/chromedriver-win64.zip
    #압축 해제 후, driver.exe는 실행파일과 같은 위치 혹은 하위에 존재해야 함
    #사내망에선 드라이버의 물리적 위치 괄호 안에 지정해줘야 함
except SessionNotCreatedException as e:
    print("SessionNotCreatedExceptions이 발생했습니다:", str(e))
driver.get(url)
time.sleep(3)

# %%
#외식 업종, 100개씩 보기, 적용 조회
driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div/div[2]/div[2]/form/div[1]/fieldset/select[2]/option[2]').click()
driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div/div[2]/div[2]/form/div[1]/fieldset/input[2]').click()
driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div/div[2]/div[2]/form/div[2]/div/select/option[4]').click()
time.sleep(3)
driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div/div[2]/div[2]/form/div[2]/div/a').click() #적용 클릭
time.sleep(3)
table = driver.find_element(By.XPATH, '/html/body/div[2]/div[3]/div/div[2]/div[2]/form/table')
tbody = table.find_element(By.TAG_NAME, 'tbody')

# %%
i = 1
data = []
line_data = []

rows = tbody.find_elements(By.TAG_NAME, "tr")

#테이블 파싱, 컬럼명 지정
for index, value in enumerate(rows):
    Name = value.find_elements(By.TAG_NAME,"td")[1].text
    Business = value.find_elements(By.TAG_NAME,"td")[2].text
    Representative = value.find_elements(By.TAG_NAME,"td")[3].text
    Registration_Number = value.find_elements(By.TAG_NAME,"td")[4].text
    Init_Date = value.find_elements(By.TAG_NAME,"td")[5].text
    Type = value.find_elements(By.TAG_NAME,"td")[6].text

    sheet.append([i, Name, Business, Representative, Registration_Number, Init_Date, Type])
    i +=1

for row in sheet.iter_rows(max_col=7, values_only=True):
    print(row)
    line_data.append(row)
    data.append(line_data)
# Out:
# ('No.', 'Name', 'Business', 'Representative', 'Registration_Number', 'Init_Date', 'Type')
# (1, '굿모닝푸드', '가마솥 닭한마리', '장윤재', '20241045', '2024.07.30', '한식')
# (2, '행운마을', '행복아래행운마을', '김회곤', '20241049', '2024.07.30', '한식')
# (3, '우와', '우와', '한정우', '20181136', '2018.11.08', '기타 외식')
# (4, '고기홀릭김치본색', '혼밥대가', '이민정', '20241048', '2024.07.30', '한식')
# (5, '(주)돼지곱닭', '돼지곱닭', '주은경', '20220142', '2022.02.22', '한식')
# (6, '대천한방통닭', '대천한방통닭', '변보련', '20230531', '2023.04.12', '치킨')
# (7, '더밀', '더밀데이', '한경은', '20220431', '2022.05.19', '서양식')
# (8, '(주)삼인조푸드', '참숯 삼인조', '송지환', '20210167', '2021.01.21', '한식')
# (9, '(주)나무기획', '캐롤커피', '박성원', '20212106', '2021.09.09', '커피')
# (10, '(주)엠디푸드시스템', '막창도둑', '김병철', '20151228', '2015.12.17', '기타 외식')
# (11, '(주)씨에스', '조선CH.S치킨', '송승권', '20080400017', '2008.07.30', '치킨')
# (12, '(주)조선대가', '조선불고기밀면', '김동준', '20220295', '2022.04.06', '한식')
# (13, '이센스', '감동카페', '최해필', '20212594', '2021.10.12', '음료 (커피 외)')
# (14, '이센스', '디저트일구', '최해필', '20212598', '2021.10.12', '기타 외식')
# (15, '이센스', '열정시대', '최해필', '20212593', '2021.10.12', '주점')
# (16, '(주)청욱', '로얄자카르타', '김봉성', '20201279', '2020.09.29', '주점')
# (17, '㈜태영푸드코리아', '2in샤브', '권태동', '20190302', '2019.04.08', '일식')
# (18, '(주)엘앤케이푸드', '몬안베띠', '임지훈', '20221363', '2022.12.09', '기타 외국식')
# (19, '(주)귀한사람들', '꽃창살', '권종철', '20231344', '2023.09.18', '기타 외식')
# (20, '(주)귀한사람들', '광안대교', '권종철', '20231346', '2023.09.18', '기타 외식')
# (21, '(주)귀한사람들', '돌판집', '권종철', '20231345', '2023.09.18', '기타 외식')
# (22, '(주)귀한사람들', '귀한족발', '권종철', '20190687', '2019.07.15', '기타 외식')
# (23, '토가돈', '토가돈', '양명애', '20221245', '2022.11.21', '한식')
# (24, '(주)티에이', '타타스베이글', '조금봉', '20220797', '2022.08.09', '제과제빵')
# (25, '(주)하이파이브', '하이오커피', '이채일', '20211005', '2021.04.09', '커피')
# (26, '(주)와이케이', '스위시(SUWiSH)', '정세민, 박윤경', '20220952', '2022.09.20', '일식')
# (27, '(주)와이케이', '갓튀김닭', '정세민, 박윤경', '20200471', '2020.04.06', '치킨')
# (28, '(주)제주곤이칼국수', '제주곤이 칼국수', '이성화', '20215580', '2021.11.17', '한식')
# (29, '브랜뉴(주)', '김바라김밥', '조민희, 안시연', '20230138', '2023.01.30', '분식')
# (30, '(주)엘케이누들', '란콰이펑누들', '김동성', '20213821', '2021.11.02', '중식')
# (31, '(주)엠지에이치', '뚱삼이와 대삼이', '송준욱', '20150944', '2015.10.05', '한식')
# (32, '(주)라이옥푸드', '라이옥베트남쌀국수', '문건우', '20220660', '2022.07.13', '기타 외국식')
# (33, '다승푸드', '밥은화', '양호승', '20190572', '2019.06.18', '한식')
# (34, '(주)올바릇', '올바릇', '지춘근', '20231766', '2023.11.30', '한식')
# (35, '(주)환공어묵베이커리', '환공어묵베이커리', '윤나라 고경진', '20150871', '2015.09.17', '기타 외식')
# (36, '빨간맛집', '빨간맛집', '고제식', '20130503', '2013.12.27', '주점')
# (37, '케이사이공', 'K420', '한대희', '20220822', '2022.08.12', '기타 외식')
# (38, '(주)빛가람에프앤비', '궁민정음', '차재환', '20230059', '2023.01.12', '기타 외식')
# (39, '(주)위드윈푸드시스템', '빅찹핫도그', '위한별', '20210201', '2021.01.22', '패스트푸드')
# (40, '(주)수봉에프에스', '룸비', '이수인', '20200386', '2020.03.18', '주점')
# (41, '(주)에브리커피', 'Every Coffee(에브리커피)', '최유라', '20214777', '2021.11.12', '커피')
# (42, '(주)진원푸드', '진원 소우', '장진철, 장원종', '20190272', '2019.04.02', '한식')
# (43, '빅그램커피베이커리', '청담김치찜', '김병찬', '20220333', '2022.04.25', '한식')
# (44, '(주)오복푸드', '오복미역', '최보규', '20160153', '2016.02.18', '한식')
# (45, '(주)브랜딩컴퍼니', '비결카페', '이영복, 김관오', '20212749', '2021.10.14', '커피')
# (46, '(주)브랜딩컴퍼니', '비결치킨', '이영복, 김관오', '20212748', '2021.10.14', '치킨')
# (47, '(주)브랜딩컴퍼니', '비결주점', '이영복, 김관오', '20212750', '2021.10.14', '주점')
# (48, '(주)브랜딩컴퍼니', '비결족발', '이영복, 김관오', '20212751', '2021.10.14', '한식')
# (49, '(주)브랜딩컴퍼니', '비결고기', '이영복, 김관오', '20212753', '2021.10.14', '한식')
# (50, '(주)빛가람에프앤비', '빛가람국밥', '차재환', '20141253', '2014.12.23', '기타 외식')
# (51, '주)돌우물', '쓰촨두보마라탕', '임정환', '20240012', '2024.01.03', '중식')
# (52, '(주)돌우물', '돌우물집', '임정환', '20231864', '2023.12.19', '한식')
# (53, '(주)돌우물', '제육집막내아들', '임정환', '20231656', '2023.11.14', '한식')
# (54, '(주)돌우물', '전지적밥상시점', '임정환', '20231499', '2023.10.16', '한식')
# (55, '(주)돌우물', '퐁치커피익스프레스', '임정환', '20221261', '2022.11.23', '커피')
# (56, '(주)돌우물', '지랄냉면', '임정환', '20220181', '2022.03.04', '한식')
# (57, '(주)돌우물', '와드커피(WAD COFFEE)', '임정환', '20214138', '2021.11.05', '커피')
# (58, '(주)돌우물', '쌍팔반점', '임정환', '20211828', '2021.08.10', '중식')
# (59, '우리집밥상', '거작 우거지감자탕', '박흥철', '20241036', '2024.07.29', '한식')
# (60, '(주)제이더블유푸드컴퍼니', '백정밥상', '정지원', '20241040', '2024.07.29', '한식')
# (61, '㈜트렌드빌더', '이태원분식포차', '김원빈', '20241043', '2024.07.29', '주점')
# (62, '(주)푸르다', '푸르파파', '지철', '20241035', '2024.07.29', '커피')
# (63, '여왕떡볶이', '여왕떡볶이', '강수화', '20241041', '2024.07.29', '분식')
# (64, '(주)음식생각', '참마음설렁탕', '김달회', '20241042', '2024.07.29', '한식')
# (65, '(주)애요스', '파슷타애요', '육지현', '20241033', '2024.07.29', '서양식')
# (66, '삼미화로', '삼미화로', '이우영', '20241034', '2024.07.29', '한식')
# (67, '(주)삼청동', '슈퍼브카페', '임한경', '20212187', '2021.09.15', '커피')
# (68, '밀바라기', '밀바라기', '김성란', '20221350', '2022.12.09', '분식')
# (69, '(주)제주소나이', '괸당집', '오용진', '20201340', '2020.10.13', '한식')
# (70, '(주)삼청동', '삼청동샤브', '임한경', '20201135', '2020.09.07', '한식')
# (71, '㈜커먼스', '앵떡볶이', '홍준표', '20210984', '2021.04.08', '분식')
# (72, '(주)커피사피엔스', '커피사피엔스', '정세현', '20171478', '2017.12.14', '커피')
# (73, '(주)호현에프앤비', '튀김장인', '김광민', '20214524', '2021.11.10', '치킨')
# (74, '(주)맥주의전설', '맥주의전설', '윤오성', '20201418', '2020.10.26', '주점')
# (75, '다원옥', '다원옥', '장현석', '20214493', '2021.11.10', '한식')
# (76, '(주)띤띤', '띤띤', '이돈희', '20190584', '2019.06.20', '기타 외국식')
# (77, '도갈비', '도갈비', '고준호', '20240071', '2024.01.12', '한식')
# (78, '케이앤씨푸드', '곽두팔씨함흥냉면', '천홍미', '20221243', '2022.11.21', '한식')
# (79, '밸라다부산본점', '밸라다(BELLADA)', '박준영', '20210722', '2021.03.15', '커피')
# (80, '막돼고', '막돼고', '이명진,이화정', '20231914', '2023.12.29', '한식')
# (81, '상구푸드', '상구네솥뚜껑삼겹살', '정부석', '20231110', '2023.08.02', '한식')
# (82, '(주)우브라더스', '육연사', '장성현', '20220400', '2022.05.11', '한식')
# (83, '대경식품', '용가마순대', '염종록', '20211204', '2021.05.18', '한식')
# (84, '(주)더투게더에프앤비', '팔도미역', '최민용', '20230196', '2023.02.08', '한식')
# (85, '(주)투빅', '투빅커피(TOOBIG COFFEE)', '김지혜', '20230612', '2023.04.28', '커피')
# (86, '(주)공일에프앤비', '오공일', '박예슬', '20240498', '2024.04.02', '한식')
# (87, '(주)푸드지니어스', '짱닭치킨', '권석영', '20110100528', '2011.11.07', '치킨')
# (88, '(주)솔푸드', '아띠몽', '허성아', '20100100323', '2010.07.12', '패스트푸드')
# (89, '(주)해피존에프앤비', '치폴레옹', '정충호', '20171541', '2017.12.19', '기타 외식')
# (90, '(주)핫넥스트', '옆집떡볶이', '정우석', '20201201', '2020.09.17', '분식')
# (91, '대흥유통', '토닭토닭양념치킨', '김진구', '20190573', '2019.06.18', '치킨')
# (92, '(주)청담패밀리', '청담딜리버리', '전제현', '20231700', '2023.11.21', '기타 외식')
# (93, '(주)케이엠제이코리아', '김미자당진아구동태찜탕', '조강희', '20171256', '2017.11.01', '한식')
# (94, '(주)기영에프앤비', '데일리버거', '강인규', '20213278', '2021.10.25', '패스트푸드')
# (95, '(주)기영에프앤비', '데일리김밥', '강인규', '20213285', '2021.10.25', '분식')
# (96, '(주)기영에프앤비', '데일리브레드', '강인규', '20213268', '2021.10.25', '제과제빵')
# (97, '(주)기영에프앤비', '데일리라이스', '강인규', '20213269', '2021.10.25', '한식')
# (98, '(주)기영에프앤비', '데일리미트', '강인규', '20213277', '2021.10.25', '한식')
# (99, '(주)기영에프앤비', '데일리반점', '강인규', '20213279', '2021.10.25', '중식')
# (100, '(주)기영에프앤비', '데일리치킨', '강인규', '20213281', '2021.10.25', '치킨')

# %%
# 정렬 전 저장
wb.save('FD_Crawling_Business_Info_System_{}.xlsx'.format(crawler_date))

# %%
xl = pd.ExcelFile('FD_Crawling_Business_Info_System_{}.xlsx'.format(crawler_date))
df = xl.parse("Sheet")
df = df.sort_values(by="Init_Date", ascending=False)
df.to_excel('FD_Crawling_Business_Info_System_{}.xlsx'.format(crawler_date), sheet_name="가맹사업정보", columns=["No.", "Name", "Business", "Representative","Registration_Number", "Init_Date","Type"],index=False)
driver.close()
